# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
temp = pd.read_csv('meta.txt')

# %%
temp.columns
# Out:
# Index(['Chromosome #', 'Number of variants', 'Number of syn variants',
#        'Number of nonsyn variants'],
#       dtype='object')

# %%
for i in temp.columns[1:]:
    plt.figure(figsize=(15,8))
    sns.barplot(temp['Chromosome #'], temp[i])
    #plt.show()
    plt.savefig(i+'.png')
